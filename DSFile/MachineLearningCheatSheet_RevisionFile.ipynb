# %%
#Data Analysis and Machine Learning Process

# %%
#Step 1: Import the libraries

# %%
#mathemetics stats
import  numpy as np
#read write functions
import pandas as pd

#plot 
import matplotlib.pyplot as plt
import seaborn as sns

#to ignore warnings
import warnings
warnings.filterwarnings("ignore")

print("All libraries are imported")

#Encoding 
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder


#Feature Scaling
from sklearn.preprocessing import StandardScaler #(#z score)
from sklearn.preprocessing import MinMaxScaler   #(Min max)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 #mathemetics stats
# ----> 2 import  numpy as np
#       3 #read write functions
#       4 import pandas as pd
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#Step 2: Read the data 
#check the data format type
df = pd.read_csv("CarPrice1.csv")
#df is dataframe. dataframe -- 2 dimension table with rows and columns

# %%
df.head(5) #prints first 5 values
# Out:
#    ar_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0      1          3        alfa-romero giulia      gas        std        two
# 1      2          3       alfa-romero stelvio      gas        std        two
# 2      3          1  alfa-romero Quadrifoglio      gas        std        two
# 3      4          2               audi 100 ls      gas        std       four
# 4      5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.tail(5) #prints last 5
# Out:
#      ar_ID  symboling          CarName fueltype aspiration doornumber carbody  \
# 200    201         -1  volvo 145e (sw)      gas        std       four   sedan
# 201    202         -1      volvo 144ea      gas      turbo       four   sedan
# 202    203         -1      volvo 244dl      gas        std       four   sedan
# 203    204         -1        volvo 246   diesel      turbo        NaN   sedan
# 204    205         -1      volvo 264gl      gas      turbo       four   sedan
#
#     drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200        rwd          front      109.1  ...         141        mpfi
# 201        rwd          front      109.1  ...         141        mpfi
# 202        rwd          front      109.1  ...         173        mpfi
# 203        rwd          front      109.1  ...         145         idi
# 204        rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
#Step 3: Find and Treat the missing values

# %%
df.shape #205 rows and 26 columns
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ar_ID             205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        196 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
#doornumber, horsepower, peakrpm has null values or missing values

# %%
#Missing values are of two types. 
#1. Standard Missing Values -- python can detect
#2. Non-Standard Missing Values -- python cannot detect ? , #, *

#all the missing values should be changed to np.nan
#np.nan --- standardised missing value

# %%
#Step 4: Get the data information and verify the variable type and change if required

# %% [markdown]
# ![image.png](attachment:89d7ce97-3ca4-4c37-82ec-b44b507b8e9a.png)![image.png](attachment:85a5b030-1881-4fff-a02c-7d8b6cb68cee.png)

# %% [markdown]
# ![image.png](attachment:73af6fa3-aaa2-4398-8b7a-2517bd8d9142.png)![image.png](attachment:8ab00395-cdbf-4fbf-8f9e-0fd41f8c8595.png)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ar_ID             205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        196 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df[['boreratio','stroke','peakrpm','price','horsepower']]=df[['boreratio','stroke','peakrpm','price','horsepower']].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df[['boreratio','stroke','peakrpm','price','horsepower']]=df[['boreratio','stroke','peakrpm','price','horsepower']].astype('float')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
df.replace("?", np.nan, inplace= True)  #converting ? to null value

# %%
df[['boreratio','stroke','peakrpm','price','horsepower']]=df[['boreratio','stroke','peakrpm','price','horsepower']].astype('float')

# %%
df[['boreratio','stroke','peakrpm','price','horsepower']].dtypes
# Out:
# boreratio     float64
# stroke        float64
# peakrpm       float64
# price         float64
# horsepower    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ar_ID             205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        196 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
#doornumber, horsepower, peakrpm has standard null value
#boreratio, stroke, price non standard null value ? -- nan

# %%
#Treating missing values

#2 Methods
#1. Drop -- column / row
#2. Replace --- 1. Mean/ Median    2. Frequency/ Mode

# %%
figure = plt.figure(figsize = (8,5))
sns.heatmap(df.isnull(),cbar = False )
# Out:
# <Axes: >

# %%
df['doornumber'].value_counts() #we can get the unique values
# Out:
# doornumber
# four    108
# two      88
# Name: count, dtype: int64

# %%
#Mode
#based on frequency / mode -- I am going treat doornumber

# %%
df['doornumber'].replace(np.nan, "four", inplace = True)

# %%
figure = plt.figure(figsize = (8,5))
sns.heatmap(df.isnull(),cbar = False )
# Out:
# <Axes: >

# %%
#When you have very less unique values -- go for Mode type

# %%
df['horsepower'].dtype
# Out:
# dtype('float64')

# %%
avg_horse = df['horsepower'].astype('float').mean()
avg_horse
# Out:
# 103.7910447761194

# %%
#put all these missing values by its mean
df['horsepower'].replace(np.nan,avg_horse, inplace = True)

# %%
figure = plt.figure(figsize = (8,5))
sns.heatmap(df.isnull(),cbar = False )
# Out:
# <Axes: >

# %%
avg_rpm = df['peakrpm'].astype('float').mean()
df['peakrpm'].replace(np.nan,avg_rpm, inplace = True)

# %%
avg_bore = df['boreratio'].astype('float').mean()
df['boreratio'].replace(np.nan,avg_bore, inplace = True)

# %%
avg_stroke = df['stroke'].astype('float').mean()
df['stroke'].replace(np.nan,avg_stroke, inplace = True)

# %%
figure = plt.figure(figsize = (8,5))
sns.heatmap(df.isnull(),cbar = False )
# Out:
# <Axes: >

# %%
avg_stroke = df['price'].astype('float').mean()
df['price'].replace(np.nan,avg_stroke, inplace = True)

# %%
figure = plt.figure(figsize = (8,5))
sns.heatmap(df.isnull(),cbar = False )
# Out:
# <Axes: >

# %%
#mean --no big outliers present 
#1l, 1.5l, 2l, 1.7l , 1.5l ---- mean (1.54l) 
#1l, 1.5l, 2l, 1.7l , 1.5l, 1cr(outlier) --- mean (17.95) should not use 
#Use median 
#al, 1.5l, 1.5l, 1.7l, 2cr
#Median (center value) --- 1.5l

#1l, 1l, 1l, 2l, 3l, 4l
#mode /ferquecy --- 1l

# %%
df.head()
# Out:
#    ar_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0      1          3        alfa-romero giulia      gas        std        two
# 1      2          3       alfa-romero stelvio      gas        std        two
# 2      3          1  alfa-romero Quadrifoglio      gas        std        two
# 3      4          2               audi 100 ls      gas        std       four
# 4      5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower      peakrpm  \
# ...

# %%
#Encoding  -- It is used to handle non - numerica data

# %%
'''N-1 Dummy Encoding 
    2.One-hot encoding
    3.Label encoding
    4.Ordinal encoding 
	5.Frequnecy encoding
	6.Target encoding'''
# Out:
# 'N-1 Dummy Encoding \n    2.One-hot encoding\n    3.Label encoding\n    4.Ordinal encoding \n\t5.Frequnecy encoding\n\t6.Target encoding'

# %%
df['fueltype'].value_counts()
# Out:
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
# The values are very less so , we can use 1st 2types---(One hot encoding, N-1 encoding )

# %%
#N-1 encoding

# %%
df = pd.get_dummies(df,columns = ['fueltype'], drop_first= True) #N-1 encoding

# %%
#pd.get_dummies(df,columns = ['fueltype'], drop_first= False) #One hot encoding

# %%
df['doornumber'].value_counts()
# Out:
# doornumber
# four    117
# two      88
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns = ['doornumber'], drop_first = False) #one hot encoding

# %%
df.head()
# Out:
#    ar_ID  symboling                   CarName aspiration      carbody  \
# 0      1          3        alfa-romero giulia        std  convertible
# 1      2          3       alfa-romero stelvio        std  convertible
# 2      3          1  alfa-romero Quadrifoglio        std    hatchback
# 3      4          2               audi 100 ls        std        sedan
# 4      5          2                audi 100ls        std        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  ...  stroke  \
# 0        rwd          front       88.6      168.8      64.1  ...    2.68
# 1        rwd          front       88.6      168.8      64.1  ...    2.68
# 2        rwd          front       94.5      171.2      65.5  ...    3.47
# 3        fwd          front       99.8      176.6      66.2  ...    3.40
# 4        4wd          front       99.4      176.6      66.4  ...    3.40
#
#    compressionratio horsepower      peakrpm  citympg highwaympg         price  \
# ...

# %%
df['aspiration'].value_counts()
# Out:
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64

# %%
#OneHot -- using sklearn
#Library
from sklearn.preprocessing import OneHotEncoder
encode = OneHotEncoder()
df_encode = pd.DataFrame(encode.fit_transform(df[['aspiration']]).toarray(), columns= ['aspiration_std','aspiration_turbo'])
df_encode.head(2)
# Out:
#    aspiration_std  aspiration_turbo
# 0             1.0               0.0
# 1             1.0               0.0

# %%
df = pd.concat([df,df_encode ], axis = 1) #axis = 1(column)

# %%
df.head(10)
# Out:
#    ar_ID  symboling                   CarName aspiration      carbody  \
# 0      1          3        alfa-romero giulia        std  convertible
# 1      2          3       alfa-romero stelvio        std  convertible
# 2      3          1  alfa-romero Quadrifoglio        std    hatchback
# 3      4          2               audi 100 ls        std        sedan
# 4      5          2                audi 100ls        std        sedan
# 5      6          2                  audi fox        std        sedan
# 6      7          1                audi 100ls        std        sedan
# 7      8          1                 audi 5000        std        wagon
# 8      9          1                 audi 4000      turbo        sedan
# 9     10          0       audi 5000s (diesel)      turbo    hatchback
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  ...  horsepower  \
# 0        rwd          front       88.6      168.8      64.1  ...       111.0
# ...

# %%
df = df.drop(['aspiration'], axis= 1)
df.head(10)
# Out:
#    ar_ID  symboling                   CarName      carbody drivewheel  \
# 0      1          3        alfa-romero giulia  convertible        rwd
# 1      2          3       alfa-romero stelvio  convertible        rwd
# 2      3          1  alfa-romero Quadrifoglio    hatchback        rwd
# 3      4          2               audi 100 ls        sedan        fwd
# 4      5          2                audi 100ls        sedan        4wd
# 5      6          2                  audi fox        sedan        fwd
# 6      7          1                audi 100ls        sedan        fwd
# 7      8          1                 audi 5000        wagon        fwd
# 8      9          1                 audi 4000        sedan        fwd
# 9     10          0       audi 5000s (diesel)    hatchback        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  ...  horsepower  \
# 0          front       88.6      168.8      64.1       48.8  ...       111.0
# ...

# %%
df.head(5)
# Out:
#    ar_ID  symboling                   CarName      carbody drivewheel  \
# 0      1          3        alfa-romero giulia  convertible        rwd
# 1      2          3       alfa-romero stelvio  convertible        rwd
# 2      3          1  alfa-romero Quadrifoglio    hatchback        rwd
# 3      4          2               audi 100 ls        sedan        fwd
# 4      5          2                audi 100ls        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  ...  horsepower  \
# 0          front       88.6      168.8      64.1       48.8  ...       111.0
# 1          front       88.6      168.8      64.1       48.8  ...       111.0
# 2          front       94.5      171.2      65.5       52.4  ...       154.0
# 3          front       99.8      176.6      66.2       54.3  ...       102.0
# 4          front       99.4      176.6      66.4       54.3  ...       115.0
#
#        peakrpm citympg  highwaympg         price  fueltype_gas  \
# ...

# %%
df['carbody'].value_counts()
# Out:
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
#Label encoding

# %%
#library 
from sklearn.preprocessing import LabelEncoder

#initialize
encode = LabelEncoder()
# dataframe 
df['carbody_encoded'] = encode.fit_transform(df['carbody'])

df.head()
# Out:
# 0    0
# 1    0
# 2    2
# 3    3
# 4    3
# Name: carbody_encoded, dtype: int32

# %%
df.drop ('carbody', inplace= True, axis = 1)

# %%
df.head()
# Out:
#    ar_ID  symboling drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0      1          3        rwd          front       88.6      168.8      64.1
# 1      2          3        rwd          front       88.6      168.8      64.1
# 2      3          1        rwd          front       94.5      171.2      65.5
# 3      4          2        fwd          front       99.8      176.6      66.2
# 4      5          2        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype  ...      peakrpm  citympg highwaympg  \
# 0       48.8        2548       dohc  ...  5000.000000       21         27
# 1       48.8        2548       dohc  ...  5000.000000       21         27
# 2       52.4        2823       ohcv  ...  5129.292929       19         26
# 3       54.3        2337        ohc  ...  5500.000000       24         30
# 4       54.3        2824        ohc  ...  5500.000000       18         22
#
# ...

# %%
df.head()
# Out:
#    ar_ID  symboling drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0      1          3        rwd          front       88.6      168.8      64.1
# 1      2          3        rwd          front       88.6      168.8      64.1
# 2      3          1        rwd          front       94.5      171.2      65.5
# 3      4          2        fwd          front       99.8      176.6      66.2
# 4      5          2        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype  ...      peakrpm  citympg highwaympg  \
# 0       48.8        2548       dohc  ...  5000.000000       21         27
# 1       48.8        2548       dohc  ...  5000.000000       21         27
# 2       52.4        2823       ohcv  ...  5129.292929       19         26
# 3       54.3        2337        ohc  ...  5500.000000       24         30
# 4       54.3        2824        ohc  ...  5500.000000       18         22
#
# ...

# %%
df['price'].describe()
# Out:
# count      205.000000
# mean     13305.381428
# std       7967.783688
# min       5118.000000
# 25%       7799.000000
# 50%      10595.000000
# 75%      16500.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
price - 7799.000000, 10595.000000, 75

# %%
def performance (price):
    if  price< 7799: 
       return 'Worst' 
    elif price<10595: 
        return 'OK'
    else :
       return 'Best'

# %%
df['performance'] = df['price'].apply(performance)

# %%
df.head()
# Out:
#    ar_ID  symboling drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0      1          3        rwd          front       88.6      168.8      64.1
# 1      2          3        rwd          front       88.6      168.8      64.1
# 2      3          1        rwd          front       94.5      171.2      65.5
# 3      4          2        fwd          front       99.8      176.6      66.2
# 4      5          2        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype  ... citympg  highwaympg         price  \
# 0       48.8        2548       dohc  ...      21          27  13495.000000
# 1       48.8        2548       dohc  ...      21          27  16500.000000
# 2       52.4        2823       ohcv  ...      19          26  16500.000000
# 3       54.3        2337        ohc  ...      24          30  13950.000000
# 4       54.3        2824        ohc  ...      18          22  13305.381428
#
# ...

# %%
#Ordinal encoding

# %%
#library 
from sklearn.preprocessing import OrdinalEncoder
#initialise
encode = OrdinalEncoder(categories = [['Worst', 'OK', 'Best']])

#fit
df['performance_encoded']= encode.fit_transform(df['performance'].values.reshape(-1,1))

df.head()
# Out:
#    ar_ID  symboling drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0      1          3        rwd          front       88.6      168.8      64.1
# 1      2          3        rwd          front       88.6      168.8      64.1
# 2      3          1        rwd          front       94.5      171.2      65.5
# 3      4          2        fwd          front       99.8      176.6      66.2
# 4      5          2        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype  ... highwaympg         price  \
# 0       48.8        2548       dohc  ...         27  13495.000000
# 1       48.8        2548       dohc  ...         27  16500.000000
# 2       52.4        2823       ohcv  ...         26  16500.000000
# 3       54.3        2337        ohc  ...         30  13950.000000
# 4       54.3        2824        ohc  ...         22  13305.381428
#
#   fueltype_gas  doornumber_four  doornumber_two  aspiration_std  \
# ...

# %%
df.drop(columns = 'performance', inplace = True, axis = 1)

# %%
df.head()
# Out:
#    ar_ID  symboling drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0      1          3        rwd          front       88.6      168.8      64.1
# 1      2          3        rwd          front       88.6      168.8      64.1
# 2      3          1        rwd          front       94.5      171.2      65.5
# 3      4          2        fwd          front       99.8      176.6      66.2
# 4      5          2        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype  ... citympg  highwaympg         price  \
# 0       48.8        2548       dohc  ...      21          27  13495.000000
# 1       48.8        2548       dohc  ...      21          27  16500.000000
# 2       52.4        2823       ohcv  ...      19          26  16500.000000
# 3       54.3        2337        ohc  ...      24          30  13950.000000
# 4       54.3        2824        ohc  ...      18          22  13305.381428
#
# ...

# %%
#frequency encoding

# %%
df['drivewheel'].value_counts()
# Out:
# drivewheel
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64

# %%
df.groupby('drivewheel').size()
# Out:
# drivewheel
# 4wd      9
# fwd    120
# rwd     76
# dtype: int64

# %%
len(df['drivewheel'])
# Out:
# 205

# %%
encode = df['drivewheel'].value_counts()/ len(df['drivewheel'])
encode
# Out:
# drivewheel
# fwd    0.585366
# rwd    0.370732
# 4wd    0.043902
# Name: count, dtype: float64

# %%
#we got the encode

#fit 
df['drivewheel_encode']=df['drivewheel'].map(encode)
df.head()
# Out:
#    ar_ID  symboling drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0      1          3        rwd          front       88.6      168.8      64.1
# 1      2          3        rwd          front       88.6      168.8      64.1
# 2      3          1        rwd          front       94.5      171.2      65.5
# 3      4          2        fwd          front       99.8      176.6      66.2
# 4      5          2        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype  ... highwaympg         price  \
# 0       48.8        2548       dohc  ...         27  13495.000000
# 1       48.8        2548       dohc  ...         27  16500.000000
# 2       52.4        2823       ohcv  ...         26  16500.000000
# 3       54.3        2337        ohc  ...         30  13950.000000
# 4       54.3        2824        ohc  ...         22  13305.381428
#
#   fueltype_gas  doornumber_four  doornumber_two  aspiration_std  \
# ...

# %%
#drop 
df.drop(columns= 'drivewheel', inplace = True, axis =1)

# %%
df.head()
# Out:
#    ar_ID  symboling enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0      1          3          front       88.6      168.8      64.1       48.8
# 1      2          3          front       88.6      168.8      64.1       48.8
# 2      3          1          front       94.5      171.2      65.5       52.4
# 3      4          2          front       99.8      176.6      66.2       54.3
# 4      5          2          front       99.4      176.6      66.4       54.3
#
#    curbweight enginetype cylindernumber  ...  highwaympg         price  \
# 0        2548       dohc           four  ...          27  13495.000000
# 1        2548       dohc           four  ...          27  16500.000000
# 2        2823       ohcv            six  ...          26  16500.000000
# 3        2337        ohc           four  ...          30  13950.000000
# 4        2824        ohc           five  ...          22  13305.381428
#
#    fueltype_gas  doornumber_four  doornumber_two  aspiration_std  \
# ...

# %%
#Feature Scaling

# %%
#z-score Normalisation

# %%
#library 
from sklearn.preprocessing import StandardScaler

#initlaise
scale = StandardScaler()

#fit
df['curbweight_scale']= scale.fit_transform(df[['curbweight']])

# %%
df.head()
# Out:
#    ar_ID  symboling enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0      1          3          front       88.6      168.8      64.1       48.8
# 1      2          3          front       88.6      168.8      64.1       48.8
# 2      3          1          front       94.5      171.2      65.5       52.4
# 3      4          2          front       99.8      176.6      66.2       54.3
# 4      5          2          front       99.4      176.6      66.4       54.3
#
#    curbweight enginetype cylindernumber  ...         price fueltype_gas  \
# 0        2548       dohc           four  ...  13495.000000         True
# 1        2548       dohc           four  ...  16500.000000         True
# 2        2823       ohcv            six  ...  16500.000000         True
# 3        2337        ohc           four  ...  13950.000000         True
# 4        2824        ohc           five  ...  13305.381428         True
#
# ...

# %%
df.drop(columns='curbweight', inplace = True, axis =1)

# %%
df.head(2)
# Out:
#    ar_ID  symboling enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0      1          3          front       88.6      168.8      64.1       48.8
# 1      2          3          front       88.6      168.8      64.1       48.8
#
#   enginetype cylindernumber  enginesize  ...    price  fueltype_gas  \
# 0       dohc           four         130  ...  13495.0          True
# 1       dohc           four         130  ...  16500.0          True
#
#    doornumber_four  doornumber_two  aspiration_std  aspiration_turbo  \
# 0            False            True             1.0               0.0
# 1            False            True             1.0               0.0
#
#    carbody_encoded  performance_encoded  drivewheel_encode  curbweight_scale
# 0                0                  2.0           0.370732         -0.014566
# 1                0                  2.0           0.370732         -0.014566
#
# [2 rows x 28 columns]

# %%
#Min-Max Normalisation

# %%
#library 

from sklearn.preprocessing import MinMaxScaler

#initialse
scale = MinMaxScaler()

#fit 
df['price'] = scale.fit_transform(df[['price']])

df.head()
# Out:
#    ar_ID  symboling enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0      1          3          front       88.6      168.8      64.1       48.8
# 1      2          3          front       88.6      168.8      64.1       48.8
# 2      3          1          front       94.5      171.2      65.5       52.4
# 3      4          2          front       99.8      176.6      66.2       54.3
# 4      5          2          front       99.4      176.6      66.4       54.3
#
#   enginetype cylindernumber  enginesize  ...     price  fueltype_gas  \
# 0       dohc           four         130  ...  0.207959          True
# 1       dohc           four         130  ...  0.282558          True
# 2       ohcv            six         152  ...  0.282558          True
# 3        ohc           four         109  ...  0.219254          True
# 4        ohc           five         136  ...  0.203252          True
#
#    doornumber_four  doornumber_two  aspiration_std  aspiration_turbo  \
# ...

# %%
#Data Transformation

# %%
sns.displot(df['compressionratio'], kde=True)

# %%
df.select_dtypes(exclude = 'O').skew()  #-infinity --- 0
# Out:
# ar_ID                  0.000000
# symboling              0.211072
# wheelbase              1.050214
# carlength              0.155954
# carwidth               0.904003
# carheight              0.063123
# enginesize             1.947655
# boreratio             -0.018976
# stroke                -0.711584
# compressionratio       2.610862
# horsepower             1.438178
# peakrpm                0.063939
# citympg                0.663704
# highwaympg             0.539997
# price                  1.783130
# fueltype_gas          -2.732619
# doornumber_four       -0.287912
# doornumber_two         0.287912
# aspiration_std        -1.673832
# aspiration_turbo       1.673832
# carbody_encoded       -0.665301
# performance_encoded   -0.504974
# drivewheel_encode     -1.339509
# curbweight_scale       0.681398
# dtype: float64

# %%
'''-∞ to -1: Highly negatively skewed
-1 to -0.5: Moderately negatively skewed
-0.5 to 0.5: Approximately symmetric
0.5 to 1: Moderately positively skewed
1 to ∞: Highly positively skewed'''
# Out:
# '-∞ to -1: Highly negatively skewed\n-1 to -0.5: Moderately negatively skewed\n-0.5 to 0.5: Approximately symmetric\n0.5 to 1: Moderately positively skewed\n1 to ∞: Highly positively skewed'

# %%
df['compressionratio_skew'] = np.log(df['compressionratio'])

# %%
df.head()
# Out:
#    ar_ID  symboling enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0      1          3          front       88.6      168.8      64.1       48.8
# 1      2          3          front       88.6      168.8      64.1       48.8
# 2      3          1          front       94.5      171.2      65.5       52.4
# 3      4          2          front       99.8      176.6      66.2       54.3
# 4      5          2          front       99.4      176.6      66.4       54.3
#
#   enginetype cylindernumber  enginesize  ... fueltype_gas  doornumber_four  \
# 0       dohc           four         130  ...         True            False
# 1       dohc           four         130  ...         True            False
# 2       ohcv            six         152  ...         True            False
# 3        ohc           four         109  ...         True             True
# 4        ohc           five         136  ...         True             True
#
# ...

# %%
df.drop(columns= 'compressionratio', inplace = True, axis = 1)

# %%
#in  the future you have change this to old value -- exponential 

df['compressionratio_exp'] = np.exp(df['compressionratio_skew'])

# %%
df.head(2)
# Out:
#    ar_ID  symboling enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0      1          3          front       88.6      168.8      64.1       48.8
# 1      2          3          front       88.6      168.8      64.1       48.8
#
#   enginetype cylindernumber  enginesize  ... doornumber_four  doornumber_two  \
# 0       dohc           four         130  ...           False            True
# 1       dohc           four         130  ...           False            True
#
#    aspiration_std  aspiration_turbo  carbody_encoded  performance_encoded  \
# 0             1.0               0.0                0                  2.0
# 1             1.0               0.0                0                  2.0
#
#    drivewheel_encode  curbweight_scale  compressionratio_skew  \
# 0           0.370732         -0.014566               2.197225
# 1           0.370732         -0.014566               2.197225
#
#    compressionratio_exp
# 0                   9.0
# 1                   9.0
#
# ...

# %%
df.drop(columns= 'compressionratio_exp', inplace = True, axis = 1)

# %%
df.head()
# Out:
#    ar_ID  symboling enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0      1          3          front       88.6      168.8      64.1       48.8
# 1      2          3          front       88.6      168.8      64.1       48.8
# 2      3          1          front       94.5      171.2      65.5       52.4
# 3      4          2          front       99.8      176.6      66.2       54.3
# 4      5          2          front       99.4      176.6      66.4       54.3
#
#   enginetype cylindernumber  enginesize  ... fueltype_gas  doornumber_four  \
# 0       dohc           four         130  ...         True            False
# 1       dohc           four         130  ...         True            False
# 2       ohcv            six         152  ...         True            False
# 3        ohc           four         109  ...         True             True
# 4        ohc           five         136  ...         True             True
#
# ...

# %%
#Outlier Treatment

# %%
#Z score  z= x-mu/ sigma

# %%
from scipy import stats

z = np.abs(stats.zscore(df['carlength']))

# %%
z
# Out:
# 0      0.426521
# 1      0.426521
# 2      0.231513
# 3      0.207256
# 4      0.207256
#          ...
# 200    1.198549
# 201    1.198549
# 202    1.198549
# 203    1.198549
# 204    1.198549
# Name: carlength, Length: 205, dtype: float64

# %%
z.describe()
# Out:
# count    205.000000
# mean       0.779572
# std        0.627845
# min        0.036505
# 25%        0.223507
# 50%        0.629655
# 75%        1.214681
# max        2.766741
# Name: carlength, dtype: float64

# %%
#z (outliers) ( -3 to 3 )  anything>2 and anything <-2
#z > 2
#z<-2

# %%
df['carlength'] = z

# %%
df.head(5)
# Out:
#    ar_ID  symboling enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0      1          3          front       88.6   0.426521      64.1       48.8
# 1      2          3          front       88.6   0.426521      64.1       48.8
# 2      3          1          front       94.5   0.231513      65.5       52.4
# 3      4          2          front       99.8   0.207256      66.2       54.3
# 4      5          2          front       99.4   0.207256      66.4       54.3
#
#   enginetype cylindernumber  enginesize  ... fueltype_gas  doornumber_four  \
# 0       dohc           four         130  ...         True            False
# 1       dohc           four         130  ...         True            False
# 2       ohcv            six         152  ...         True            False
# 3        ohc           four         109  ...         True             True
# 4        ohc           five         136  ...         True             True
#
# ...

# %%
df.count()
# Out:
# ar_ID                    205
# symboling                205
# enginelocation           205
# wheelbase                205
# carlength                205
# carwidth                 205
# carheight                205
# enginetype               205
# cylindernumber           205
# enginesize               205
# fuelsystem               205
# boreratio                205
# stroke                   205
# horsepower               205
# peakrpm                  205
# citympg                  205
# highwaympg               205
# price                    205
# fueltype_gas             205
# doornumber_four          205
# doornumber_two           205
# aspiration_std           205
# aspiration_turbo         205
# carbody_encoded          205
# performance_encoded      205
# drivewheel_encode        205
# curbweight_scale         205
# compressionratio_skew    205
# dtype: int64

# %%
df = df[df['carlength']<2]

# %%
df.count()
# Out:
# ar_ID                    192
# symboling                192
# enginelocation           192
# wheelbase                192
# carlength                192
# carwidth                 192
# carheight                192
# enginetype               192
# cylindernumber           192
# enginesize               192
# fuelsystem               192
# boreratio                192
# stroke                   192
# horsepower               192
# peakrpm                  192
# citympg                  192
# highwaympg               192
# price                    192
# fueltype_gas             192
# doornumber_four          192
# doornumber_two           192
# aspiration_std           192
# aspiration_turbo         192
# carbody_encoded          192
# performance_encoded      192
# drivewheel_encode        192
# curbweight_scale         192
# compressionratio_skew    192
# dtype: int64

# %%
#IQR

# %%
#IQR --Interquartile range

# %%
df.describe()
# Out:
#             ar_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  192.000000  192.000000  192.000000  192.000000  192.000000  192.000000
# mean   105.177083    0.864583   98.107292    0.680575   65.745312   53.622396
# std     60.095473    1.254268    4.756241    0.511267    1.920318    2.386517
# min      1.000000   -2.000000   88.600000    0.036505   61.800000   47.800000
# 25%     53.750000    0.000000   94.500000    0.190886   64.075000   52.000000
# 50%    105.500000    1.000000   96.550000    0.548402   65.400000   54.100000
# 75%    157.250000    2.000000  100.400000    1.198549   66.500000   55.500000
# max    205.000000    3.000000  110.000000    1.954087   72.300000   59.800000
#
#        enginesize   boreratio      stroke  horsepower  ...     citympg  \
# count  192.000000  192.000000  192.000000  192.000000  ...  192.000000
# mean   123.343750    3.327197    3.248646  102.683147  ...   25.307292
# ...

# %%
#IQR

# %%
df.head()
# Out:
#    ar_ID  symboling enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0      1          3          front       88.6   0.426521      64.1       48.8
# 1      2          3          front       88.6   0.426521      64.1       48.8
# 2      3          1          front       94.5   0.231513      65.5       52.4
# 3      4          2          front       99.8   0.207256      66.2       54.3
# 4      5          2          front       99.4   0.207256      66.4       54.3
#
#   enginetype cylindernumber  enginesize  ... fueltype_gas  doornumber_four  \
# 0       dohc           four         130  ...         True            False
# 1       dohc           four         130  ...         True            False
# 2       ohcv            six         152  ...         True            False
# 3        ohc           four         109  ...         True             True
# 4        ohc           five         136  ...         True             True
#
# ...

# %%
Q1 =df['wheelbase'].quantile(0.25) #%25
Q3 =df['wheelbase'].quantile(0.75) #%75

IQR = Q3-Q1 #(75%- 25%)

# %%
IQR
# Out:
# 5.900000000000006

# %%
#IQR --------- Q1-1.5*IQR , Q3+1.5*IQR

# %%
df1= df.copy()

# %%
df1= df1[(df1['wheelbase']> (Q1-1.5*IQR))& (df1['wheelbase']< (Q3+1.5*IQR)) ]

# %%
df= df1

# %%
df.shape
# Out:
# (189, 28)

# %%
df.head()
# Out:
#    ar_ID  symboling enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0      1          3          front       88.6   0.426521      64.1       48.8
# 1      2          3          front       88.6   0.426521      64.1       48.8
# 2      3          1          front       94.5   0.231513      65.5       52.4
# 3      4          2          front       99.8   0.207256      66.2       54.3
# 4      5          2          front       99.4   0.207256      66.4       54.3
#
#   enginetype cylindernumber  enginesize  ... fueltype_gas  doornumber_four  \
# 0       dohc           four         130  ...         True            False
# 1       dohc           four         130  ...         True            False
# 2       ohcv            six         152  ...         True            False
# 3        ohc           four         109  ...         True             True
# 4        ohc           five         136  ...         True             True
#
# ...

# %%
df.drop(columns= 'ar_ID', inplace = True, axis =1)

# %%
df.head()
# Out:
#    symboling enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0          3          front       88.6   0.426521      64.1       48.8
# 1          3          front       88.6   0.426521      64.1       48.8
# 2          1          front       94.5   0.231513      65.5       52.4
# 3          2          front       99.8   0.207256      66.2       54.3
# 4          2          front       99.4   0.207256      66.4       54.3
#
#   enginetype cylindernumber  enginesize fuelsystem  ...  fueltype_gas  \
# 0       dohc           four         130       mpfi  ...          True
# 1       dohc           four         130       mpfi  ...          True
# 2       ohcv            six         152       mpfi  ...          True
# 3        ohc           four         109       mpfi  ...          True
# 4        ohc           five         136       mpfi  ...          True
#
#    doornumber_four  doornumber_two  aspiration_std  aspiration_turbo  \
# ...

# %%
#Train test split 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 189 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   symboling              189 non-null    int64
#  1   enginelocation         189 non-null    object
#  2   wheelbase              189 non-null    float64
#  3   carlength              189 non-null    float64
#  4   carwidth               189 non-null    float64
#  5   carheight              189 non-null    float64
#  6   enginetype             189 non-null    object
#  7   cylindernumber         189 non-null    object
#  8   enginesize             189 non-null    int64
#  9   fuelsystem             189 non-null    object
#  10  boreratio              189 non-null    float64
#  11  stroke                 189 non-null    float64
#  12  horsepower             189 non-null    float64
#  13  peakrpm                189 non-null    float64
# ...

# %%
#library 
from sklearn.model_selection import train_test_split

y = df['price']
X= df.drop(columns = 'price', axis =1)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state =2)

# %%
x_train.shape
# Out:
# (132, 26)

# %%
x_test.shape
# Out:
# (57, 26)

# %%
y_train.shape
# Out:
# (132,)

# %%
y_test.shape
# Out:
# (57,)

# %%
#*************END OF EDA********************
